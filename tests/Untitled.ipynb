# %%
from scipy.io import loadmat

# %%
data = loadmat('Senucspe_0/nmr.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Thu Jun 22 08:47:42 2000',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Mealy': array([[5.88636303],
#         [3.3360467 ],
#         [7.42386341],
#         [2.13522744],
#         [4.11444378],
#         [3.77159095],
#         [2.16400003],
#         [2.55599999],
#         [3.14814806],
#         [3.04799986],
#         [2.18888903],
#         [2.27037024],
#         [2.28800011],
#         [2.53600025],
#         [1.8440001 ],
#         [2.25199986],
#         [2.24000025],
#         [2.22962952],
#         [1.81199992],
#         [1.65200031],
#         [5.16551733],
#         [2.72241354],
#         [7.02413797],
#         [1.92586207],
#         [3.10517263],
#         [3.01206875]]),
#  'cpmgmraa': array([[4313.48144531, 4237.63867188, 4175.69628906, ...,   82.35023499,
#            80.88580322,   81.55575562],
#         [4403.85986328, 4338.92529297, 4283.12597656, ...,  148.81735229,
# ...

# %%
data['cpmgmraa']
# Out:
# array([[4313.48144531, 4237.63867188, 4175.69628906, ...,   82.35023499,
#           80.88580322,   81.55575562],
#        [4403.85986328, 4338.92529297, 4283.12597656, ...,  148.81735229,
#          150.70549011,  148.5572052 ],
#        [4170.32080078, 4083.76538086, 4011.49462891, ...,   92.51477814,
#           93.64325714,   92.98376465],
#        ...,
#        [4299.46484375, 4252.89990234, 4214.78613281, ...,  186.39070129,
#          186.70033264,  186.34364319],
#        [4155.11816406, 4091.11816406, 4040.97265625, ...,  105.61107635,
#          105.75592041,  105.70658875],
#        [4192.18847656, 4129.65527344, 4082.86767578, ...,  109.36238098,
#          111.22902679,  109.61743164]], shape=(26, 4096))

# %%
data['cpmgmraa'][0]
# Out:
# array([4313.48144531, 4237.63867188, 4175.69628906, ...,   82.35023499,
#          80.88580322,   81.55575562], shape=(4096,))

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]

# %%
y=[1,4,9,16]

# %%
plt.plot(x,y)

# %%
import numpy as np

# %%
x = np.arange(data['cpmgmraa'][0].shape[0])

plt.figure(figsize=(10, 4))
plt.scatter(x, data['cpmgmraa'][0], s=5, alpha=0.6)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Scatter Plot of the 4096-Point Array')
plt.grid(True)
plt.tight_layout()
plt.show()
